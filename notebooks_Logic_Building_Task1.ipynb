# %%
username='admin'
password='1234'
username1=input("Enter the name:-")
password1=input("Enter the password:-")
if username1==username and password1==password:
    print("Login is successful")
else:
    print("Incorrect username and password")
# Out:
# Enter the name:- admin
# Enter the password:- 1234
# Login is successful

# %%
marks=[45,78,90,33,60]
passcount=0
failcount=0
for mark in marks:
    if(mark>=50):
        passcount=passcount+1
    else:
        failcount=failcount+1
print("Total number of pass student",passcount)
print("Total number of fail student",failcount)
# Out:
# Total number of pass student 3
# Total number of fail student 2

# %%
names = [" Alice ", "bob", " CHARLIE "]
cleaned_names = []
for name in names:
    cleaned_name = name.strip().lower()
    cleaned_names.append(cleaned_name)
print("Cleaned Names List:", cleaned_names)
# Out:
# Cleaned Names List: ['alice', 'bob', 'charlie']

# %%
messages=["hi","welcome to the platform","OK"]
for message in messages:
    length=len(message)
    print("message=",message)
    print("length of messages=",length)
    if length>=10:
        print("\n This message is longer than 10 characters \n")
# Out:
# message= hi
# length of messages= 2
# message= welcome to the platform
# length of messages= 23
#
#  This message is longer than 10 characters
#
# message= OK
# length of messages= 2

# %%
logs=["INFO","ERROR","WARNING","ERROR"]
ecount=0
for i in logs:
    if i=='ERROR':
        ecount=ecount+1
print("Errorcount = ",ecount)
# Out:
# Errorcount =  2
